# %% [markdown]
# #### 第一次讀書會專案：針對PTT軍事版以及八卦版中對於美國出兵伊朗相關文章之情緒分析
# ##### 組別：Group_3
# ##### 組員：
# * M144020008 洪宏林
# * M144020017 陳姿佑
# * M144020019 顏志豪
# * M144020058 黄鈞浩
# * M144020020 吳俊廷
# * M144020028 白茗仁
# * M144020061 黃博章
# * B124020008 李怡君

# %% [markdown]
# #### 大綱
